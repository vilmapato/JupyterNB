# %%
import requests
url='https://www.coingecko.com/'

# %%
# Fetch top 10 cryptocurrencies by market cap
response = requests.get(
    'https://api.coingecko.com/api/v3/coins/markets',
    params={
        'vs_currency': 'usd',
        'order': 'market_cap_desc',
        'per_page': 10,
        'page': 1
    }
)
top_coins = response.json()
top_coins
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 97247,
#   'market_cap': 1927374655842,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1927374655842,
#   'total_volume': 56230169418,
#   'high_24h': 100097,
#   'low_24h': 95820,
#   'price_change_24h': 593.37,
#   'price_change_percentage_24h': 0.61392,
#   'market_cap_change_24h': 12893072170,
#   'market_cap_change_percentage_24h': 0.67345,
#   'circulating_supply': 19821043.0,
#   'total_supply': 19821043.0,
#   'max_supply': 21000000.0,
#   'ath': 108786,
#   'ath_change_percentage': -10.34199,
#   'ath_date': '2025-01-20T09:11:54.494Z',
#   'atl': 67.81,
#   'atl_change_percentage': 143737.7502,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-02-07T17:22:12.182Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 2665.03,
#   'market_cap': 323607805964,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 323607805964,
#   'total_volume': 30329541168,
#   'high_24h': 2794.36,
#   'low_24h': 2663.93,
#   'price_change_24h': -40.95747627323544,
#   'price_change_percentage_24h': -1.51359,
#   'market_cap_change_24h': -2379955297.2002563,
#   'market_cap_change_percentage_24h': -0.73008,
#   'circulating_supply': 120530911.5054202,
#   'total_supply': 120530911.5054202,
#   'max_supply': None,
#   'ath': 4878.26,
#   'ath_change_percentage': -45.29777,
#   'ath_date': '2021-11-10T14:24:19.604Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 616215.87662,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 35.60036696759061,
#    'currency': 'btc',
#    'percentage': 3560.0366967590608},
#   'last_updated': '2025-02-07T17:22:10.684Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 1.0,
#   'market_cap': 141407932701,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 141407932701,
#   'total_volume': 84834816239,
#   'high_24h': 1.001,
#   'low_24h': 1.0,
#   'price_change_24h': 0.00015468,
#   'price_change_percentage_24h': 0.01546,
#   'market_cap_change_24h': 210235926,
#   'market_cap_change_percentage_24h': 0.14889,
#   'circulating_supply': 141355200814.963,
#   'total_supply': 141355200814.963,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.39178,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.7305,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-02-07T17:22:08.454Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 2.42,
#   'market_cap': 140112021466,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 242532788854,
#   'total_volume': 7616925635,
#   'high_24h': 2.53,
#   'low_24h': 2.29,
#   'price_change_24h': 0.098166,
#   'price_change_percentage_24h': 4.21913,
#   'market_cap_change_24h': 6427672403,
#   'market_cap_change_percentage_24h': 4.8081,
#   'circulating_supply': 57762545657.0,
#   'total_supply': 99986504676.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -28.46519,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 90402.143,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-02-07T17:22:01.551Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 194.73,
#   'market_cap': 95610054493,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 116350761598,
#   'total_volume': 5423487834,
#   'high_24h': 202.86,
#   'low_24h': 188.37,
#   'price_change_24h': 4.74,
#   'price_change_percentage_24h': 2.49734,
#   'market_cap_change_24h': 3130582685,
#   'market_cap_change_percentage_24h': 3.38516,
#   'circulating_supply': 487720145.4000937,
#   'total_supply': 593521368.2762663,
#   'max_supply': None,
#   'ath': 293.31,
#   'ath_change_percentage': -33.57491,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 38804.20861,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2025-02-07T17:22:03.613Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 577.7,
#   'market_cap': 84732156966,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 84732156966,
#   'total_volume': 779594041,
#   'high_24h': 590.38,
#   'low_24h': 572.13,
#   'price_change_24h': 3.86,
#   'price_change_percentage_24h': 0.67301,
#   'market_cap_change_24h': 1013620092,
#   'market_cap_change_percentage_24h': 1.21075,
#   'circulating_supply': 145887575.79,
#   'total_supply': 145887575.79,
#   'max_supply': 200000000.0,
#   'ath': 788.84,
#   'ath_change_percentage': -26.64473,
#   'ath_date': '2024-12-04T10:35:25.220Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1453169.19265,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-02-07T17:22:08.539Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/usdc.png?1696506694',
#   'current_price': 0.999939,
#   'market_cap': 55992503208,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 56208349526,
#   'total_volume': 11544037446,
#   'high_24h': 1.0,
#   'low_24h': 0.999894,
#   'price_change_24h': -5.421542936479e-05,
#   'price_change_percentage_24h': -0.00542,
#   'market_cap_change_24h': 305096678,
#   'market_cap_change_percentage_24h': 0.54787,
#   'circulating_supply': 55992742194.26902,
#   'total_supply': 56208589433.64354,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.73287,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.93342,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2025-02-07T17:22:11.159Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.249538,
#   'market_cap': 36925354199,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 36931841959,
#   'total_volume': 1997141402,
#   'high_24h': 0.261014,
#   'low_24h': 0.243961,
#   'price_change_24h': 0.0014011,
#   'price_change_percentage_24h': 0.56465,
#   'market_cap_change_24h': 309791731,
#   'market_cap_change_percentage_24h': 0.84607,
#   'circulating_supply': 147923166383.7052,
#   'total_supply': 147949156383.7052,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -65.8347,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 287512.29846,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-02-07T17:22:09.809Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.717165,
#   'market_cap': 25981700284,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 32565505803,
#   'total_volume': 922747146,
#   'high_24h': 0.749167,
#   'low_24h': 0.701785,
#   'price_change_24h': 0.00591685,
#   'price_change_percentage_24h': 0.8319,
#   'market_cap_change_24h': 495590627,
#   'market_cap_change_percentage_24h': 1.94455,
#   'circulating_supply': 35902298580.9121,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -76.71455,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 3633.49972,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2025-02-07T17:22:09.718Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://coin-images.coingecko.com/coins/images/13442/large/steth_logo.png?1696513206',
#   'current_price': 2660.94,
#   'market_cap': 25091390921,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 25091567600,
#   'total_volume': 107162454,
#   'high_24h': 2796.64,
#   'low_24h': 2664.39,
#   'price_change_24h': -38.52143120363189,
#   'price_change_percentage_24h': -1.42701,
#   'market_cap_change_24h': -405734956.8578987,
#   'market_cap_change_percentage_24h': -1.5913,
#   'circulating_supply': 9418767.071902452,
#   'total_supply': 9418833.393634902,
#   'max_supply': None,
#   'ath': 4829.57,
#   'ath_change_percentage': -44.13732,
#   'ath_date': '2021-11-10T14:40:47.256Z',
#   'atl': 482.9,
#   'atl_change_percentage': 458.69722,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2025-02-07T17:22:02.932Z'}]

# %%
from datetime import datetime, timedelta

# Function to fetch historical data
def fetch_historical_data(coin_id):
    end_date = datetime.now()
    start_date = end_date - timedelta(days=30)
    response = requests.get(
        f'https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart/range',
        params={
            'vs_currency': 'usd',
            'from': int(start_date.timestamp()),
            'to': int(end_date.timestamp())
        }
    )
    return response.json()

# Fetch historical data for each top coin
historical_data = {}
for coin in top_coins:
    coin_id = coin['id']
    historical_data[coin_id] = fetch_historical_data(coin_id)

# %%
from collections import defaultdict

# Function to process historical data
def process_historical_data(data):
    if 'prices' not in data:
        return {}
    prices = data['prices']
    daily_prices = defaultdict(list)
    for timestamp, price in prices:
        date = datetime.fromtimestamp(timestamp / 1000).date()
        daily_prices[date].append(price)
    daily_open_close = {
        date: {'open': prices[0], 'close': prices[-1]}
        for date, prices in daily_prices.items()
    }
    return daily_open_close

# Process historical data for each coin
processed_data = {}
